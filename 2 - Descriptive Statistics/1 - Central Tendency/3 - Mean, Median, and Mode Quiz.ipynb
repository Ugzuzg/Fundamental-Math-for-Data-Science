# %% [markdown]
# <style>
# :checked + span {
#     color: red;
# }
# .correct_answer:checked + span {
#         color: green;
# }
# </style>
#
# 1. What is the mean of the dataset below?
#
#     $$
#     \{4,6,7,3\}
#     $$
#
#     <div>
#         <label>
#             <input type="radio" name="quiz1">
#             <span>
#                 6
#             </span>
#         </label>
#     </div>
#     <div>
#         <label>
#             <input type="radio" name="quiz1">
#             <span>
#                 3
#             </span>
#         </label>
#     </div>
#     <div>
#         <label>
#             <input class="correct_answer" type="radio" name="quiz1">
#             <span>
#                 5
#             </span>
#         </label>
#     </div>
#     <div>
#         <label>
#             <input type="radio" name="quiz1">
#             <span>
#                 4
#             </span>
#         </label>
#     </div>
#
# 2. Complete the following statement: The median of a dataset is…
#
#     <div>
#         <label>
#             <input type="radio" name="quiz2">
#             <span>
#                 The median of a dataset is the most frequently occurring observation in the dataset. A dataset can have multiple medians if there is more than one value with the same maximum frequency.
#             </span>
#         </label>
#     </div>
#     <div>
#         <label>
#             <input type="radio" name="quiz2">
#             <span>
#                 The median of a dataset is calculated by adding all of the values of the set together, then dividing the sum by the number of values in the set.
#             </span>
#         </label>
#     </div>
#     <div>
#         <label>
#             <input class="correct_answer" type="radio" name="quiz2">
#             <span>
#                 The median of a dataset is the value that, assuming the dataset is ordered from smallest to largest, falls in the middle. If there are an even number of values in a dataset, the middle two values are the median.
#             </span>
#         </label>
#     </div>
#     <div>
#         <label>
#             <input type="radio" name="quiz2">
#             <span>
#                 The median of a dataset is a measure of its spread. It is calculated by finding the average of the squared differences between every observation and the mean. The resulting value is in units squared.
#             </span>
#         </label>
#     </div>
#
# 3. Find the mean, median, and mode of the following dataset.
#
#     $$
#     \{10, 13, 7, 10, 5, 15\}
#     $$
#
#     <div>
#         <label>
#             <input type="radio" name="quiz3">
#             <span>
#                 mean: 10 median: 7 mode: 7
#             </span>
#         </label>
#     </div>
#     <div>
#         <label>
#             <input type="radio" name="quiz3">
#             <span>
#                 mean: 9.5 median: 7 mode: 10
#             </span>
#         </label>
#     </div>
#     <div>
#         <label>
#             <input type="radio" name="quiz3">
#             <span>
#                 mean: 11.5 median: 13 mode: 10
#             </span>
#         </label>
#     </div>
#     <div>
#         <label>
#             <input class="correct_answer" type="radio" name="quiz3">
#             <span>
#                 mean: 10 median: 10 mode: 10
#             </span>
#         </label>
#     </div>
#
# 4. Calculate the median of `my_array`, and save the result to `my_array_median`.
#
#     ```python
#     import ___ as ___
#
#     my_array = [3, 14, 15, 110, 7, 2, 1, 3, 22, 5, 10, 17, 2, 21]
#
#     ___ = ___.___(___)
#     ```
#
#     - `stats`
#     - `scipy`
#     - `my_array_median`
#     - `average`
#     - `numpy`
#     - `np`
#     - `median`
#     - `np`
#     - `my_array`
#
#     <details>
#         <summary>Answer</summary>
#
#     ```python
#     import numpy as np
#
#     my_array = [3, 14, 15, 110, 7, 2, 1, 3, 22, 5, 10, 17, 2, 21]
#
#     my_array_median = np.median(my_array)
#     ```
#     </details>
#
# 5. Calculate the mode of `my_array`, and save the result to `my_array_mode`.
#
#     ```python
#     import ___ as ___
#
#     my_array = [3, 14, 15, 110, 7, 2, 1, 3, 22, 5, 10, 17, 2, 21]
#
#     ___ = ___.___(___)
#     ```
#
#     - `mode`
#     - `np`
#     - `my_array_mode`
#     - `my_array`
#     - `stats`
#     - `scipy`
#     - `median`
#     - `numpy`
#     - `stats`
#
#     <details>
#         <summary>Answer</summary>
#
#     ```python
#     import scipy as stats
#
#     my_array = [3, 14, 15, 110, 7, 2, 1, 3, 22, 5, 10, 17, 2, 21]
#
#     my_array_mode = stats.mode(my_array)
#     ```
#     </details>
#
# 6. What is the mode of the following dataset?
#
#     $$
#     \{6, 8, 9, 22, 90, 45, 2, 22, 45, 8, 22, 6, 7\}
#     $$
#
#     <div>
#         <label>
#             <input type="radio" name="quiz6">
#             <span>
#                 45
#             </span>
#         </label>
#     </div>
#     <div>
#         <label>
#             <input class="correct_answer" type="radio" name="quiz6">
#             <span>
#                 22
#             </span>
#         </label>
#     </div>
#     <div>
#         <label>
#             <input type="radio" name="quiz6">
#             <span>
#                 6
#             </span>
#         </label>
#     </div>
#     <div>
#         <label>
#             <input type="radio" name="quiz6">
#             <span>
#                 8
#             </span>
#         </label>
#     </div>
#
# 7. What is the median of the dataset?
#
#     $$
#     \{3,4,1,19,2,1,6\}
#     $$
#
#     <div>
#         <label>
#             <input type="radio" name="quiz7">
#             <span>
#                 4
#             </span>
#         </label>
#     </div>
#     <div>
#         <label>
#             <input type="radio" name="quiz7">
#             <span>
#                 6
#             </span>
#         </label>
#     </div>
#     <div>
#         <label>
#             <input type="radio" name="quiz7">
#             <span>
#                 1
#             </span>
#         </label>
#     </div>
#     <div>
#         <label>
#             <input class="correct_answer" type="radio" name="quiz7">
#             <span>
#                 3
#             </span>
#         </label>
#     </div>
#
# 8. What is wrong with the following formula, which is meant to calculate the mean of a dataset?
#
#     $$
#     \bar{x} = x_1 + x_2 … + x_{n}
#     $$
#
#     <div>
#         <label>
#             <input class="correct_answer" type="radio" name="quiz8">
#             <span>
#                 The sum of the values in the dataset must be divided by the number of values in the dataset (<code>n</code>).
#             </span>
#         </label>
#     </div>
#     <div>
#         <label>
#             <input type="radio" name="quiz8">
#             <span>
#                 The values in the dataset should be multiplied together.
#             </span>
#         </label>
#     </div>
#     <div>
#         <label>
#             <input type="radio" name="quiz8">
#             <span>
#                 The mean of a dataset, is the value that, assuming the dataset is ordered from smallest to largest, falls in the middle.
#             </span>
#         </label>
#     </div>
#     <div>
#         <label>
#             <input type="radio" name="quiz8">
#             <span>
#                 You need to take the square root of all values in the dataset.
#             </span>
#         </label>
#     </div>
#
# 9. What is the mode of the following dataset?
#
#     $$
#     \{15, 8, 9, 15, 12, 13, 2, 15, 13, 8, 13, 6, 7\}
#     $$
#
#     <div>
#         <label>
#             <input class="correct_answer" type="radio" name="quiz9">
#             <span>
#                 13 and 15
#             </span>
#         </label>
#     </div>
#     <div>
#         <label>
#             <input type="radio" name="quiz9">
#             <span>
#                 8 and 13
#             </span>
#         </label>
#     </div>
#     <div>
#         <label>
#             <input type="radio" name="quiz9">
#             <span>
#                 13
#             </span>
#         </label>
#     </div>
#     <div>
#         <label>
#             <input type="radio" name="quiz9">
#             <span>
#                 15
#             </span>
#         </label>
#     </div>
#
# 10. Calculate the average of `my_array`, and save the result to `my_array_average`.
#
#     ```python
#     import ___ as ___
#
#     my_array = [3, 4, 5, 7, 2, 1]
#
#     ___ = ___.___(___)
#     ```
#
#     - `my_array`
#     - `stats`
#     - `np`
#     - `average`
#     - `my_array_average`
#     - `np`
#     - `combine`
#     - `scipy`
#     - `numpy`
#
#     <details>
#         <summary>Answer</summary>
#
#     ```python
#     import numpy as np
#
#     my_array = [3, 4, 5, 7, 2, 1]
#
#     my_array_average = np.average(my_array)
#     ```
#     </details>
