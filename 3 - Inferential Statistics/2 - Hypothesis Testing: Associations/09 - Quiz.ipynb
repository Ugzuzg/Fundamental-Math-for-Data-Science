# %% [markdown]
# <style>
# :checked + span {
#     color: red;
# }
# .correct_answer:checked + span {
#         color: green;
# }
# </style>
#
# 1. Suppose we want to know if a particular drug can reduce blood pressure in adults. To answer this question, we find a random sample of 200 adults and measure their blood pressure. Then, we give them the drug, wait 30 minutes, and measure their blood pressure again. Histograms of these patients’ blood pressure before and after receiving the drug are shown below:
#
#     ![overlapping histograms showing blood pressure before and after taking a drug. Both distributions look approximately normal and have similar spread. Blood pressure is higher before taking the drug than after.](../assets/bps.svg)
#
#     Which of the following assumptions of a two-sample t-test is violated by this study?
#
#
#     <div>
#         <label>
#             <input type="radio" name="quiz1">
#             <span>
#                 Random sampling from the population of interest
#             </span>
#         </label>
#     </div>
#     <div>
#         <label>
#             <input type="radio" name="quiz1">
#             <span>
#                 Normally distributed data
#             </span>
#         </label>
#     </div>
#     <div>
#         <label>
#             <input class="correct_answer" type="radio" name="quiz1">
#             <span>
#                 Independent groups
#             </span>
#         </label>
#     </div>
#     <div>
#         <label>
#             <input type="radio" name="quiz1">
#             <span>
#                 Equal standard deviations for the two groups (before vs. after the drug)
#             </span>
#         </label>
#     </div>
#
# 2. Suppose that we ran Tukey’s Range Test to compare the average grams of sugar in different brands of chocolate, vanilla, and strawberry icecreams. Based on the results below, which of the following is true?
#
#     ```
#     Multiple Comparison of Means - Tukey HSD,FWER=0.05
#     ==========================================
#     group1 group2 meandiff lower upper reject
#     ------------------------------------------
#      vanil   choc    1.16  0.01  3.03  True
#       choc strawb    5.23  2.03  8.43  True
#     strawb  vanil   -2.12 -5.28  0.98  False
#     ------------------------------------------
#     ```
#
#     <div>
#         <label>
#             <input type="radio" name="quiz2">
#             <span>
#                 There is NOT a significant difference in sugar content for chocolate vs. vanilla.
#             </span>
#         </label>
#     </div>
#     <div>
#         <label>
#             <input type="radio" name="quiz2">
#             <span>
#                 There is NOT a significant difference in sugar content for chocolate vs. strawberry.
#             </span>
#         </label>
#     </div>
#     <div>
#         <label>
#             <input class="correct_answer" type="radio" name="quiz2">
#             <span>
#                 There is a significant difference in sugar content for chocolate versus vanilla.
#             </span>
#         </label>
#     </div>
#     <div>
#         <label>
#             <input type="radio" name="quiz2">
#             <span>
#                 There is a significant difference in sugar content for strawberry versus vanilla.
#             </span>
#         </label>
#     </div>
#
# 3. What kind of hypothesis test would be appropriate to address the following question: Is there an association between whether or not someone got a Covid-19 vaccine and whether or not they had symptoms of Covid-19?
#
#     <div>
#         <label>
#             <input class="correct_answer" type="radio" name="quiz3">
#             <span>
#                 Chi-Square test
#             </span>
#         </label>
#     </div>
#     <div>
#         <label>
#             <input type="radio" name="quiz3">
#             <span>
#                 Binomial test
#             </span>
#         </label>
#     </div>
#     <div>
#         <label>
#             <input type="radio" name="quiz3">
#             <span>
#                 ANOVA
#             </span>
#         </label>
#     </div>
#     <div>
#         <label>
#             <input type="radio" name="quiz3">
#             <span>
#                 Two-sample t-test
#             </span>
#         </label>
#     </div>
#
# 4. Which of the following is a reason why a data scientist might choose to run an ANOVA and Tukey’s Range test instead of multiple two-sample t-tests?
#
#     <div>
#         <label>
#             <input class="correct_answer" type="radio" name="quiz4">
#             <span>
#                 To ensure that the type I error rate is 5% overall
#             </span>
#         </label>
#     </div>
#     <div>
#         <label>
#             <input type="radio" name="quiz4">
#             <span>
#                 To increase the chances of a significant result
#             </span>
#         </label>
#     </div>
#     <div>
#         <label>
#             <input type="radio" name="quiz4">
#             <span>
#                 ANOVA and Tukey's range test are more accurate
#             </span>
#         </label>
#     </div>
#     <div>
#         <label>
#             <input type="radio" name="quiz4">
#             <span>
#                 To test for an association between two quantitative variables
#             </span>
#         </label>
#     </div>
#
# 5. What kind of hypothesis test is appropriate for the following question: Do professional hockey players tend to weigh more (on average) than professional basketball players (is there an association between sport — hockey vs. basketball — and weight)?
#
#     <div>
#         <label>
#             <input type="radio" name="quiz5">
#             <span>
#                 Binomial test
#             </span>
#         </label>
#     </div>
#     <div>
#         <label>
#             <input type="radio" name="quiz5">
#             <span>
#                 One-sample t-test
#             </span>
#         </label>
#     </div>
#     <div>
#         <label>
#             <input type="radio" name="quiz5">
#             <span>
#                 Chi-Square test
#             </span>
#         </label>
#     </div>
#     <div>
#         <label>
#             <input class="correct_answer" type="radio" name="quiz5">
#             <span>
#                 Two-sample t-test
#             </span>
#         </label>
#     </div>
#
# 6. Suppose that a company has four different offices where employees can work. We want to know if there is an association between office location and salary: are employees at these offices earning significantly different salaries on average?
#
#     Our null hypothesis is that all of the offices have the same average salary and our alternative hypothesis is that at least one pair of offices have different average salaries. Which hypothesis test would be appropriate?
#
#
#     <div>
#         <label>
#             <input class="correct_answer" type="radio" name="quiz6">
#             <span>
#                 ANOVA
#             </span>
#         </label>
#     </div>
#     <div>
#         <label>
#             <input type="radio" name="quiz6">
#             <span>
#                 Chi-Square test
#             </span>
#         </label>
#     </div>
#     <div>
#         <label>
#             <input type="radio" name="quiz6">
#             <span>
#                 Two-sample t-test
#             </span>
#         </label>
#     </div>
#     <div>
#         <label>
#             <input type="radio" name="quiz6">
#             <span>
#                 Binomial test
#             </span>
#         </label>
#     </div>
#
# 7. Suppose that we randomly select 500 people to complete a survey. We ask them to report the type of pet(s) that they own and whether they live in a rural or urban area. We then run a Chi-Square test to see if there is an association between the location of a person’s home and what kind of pets they own. Which assumptions, if any, of a Chi-Square test are violated by this study?
#
#     <div>
#         <label>
#             <input type="radio" name="quiz7">
#             <span>
#                 Random sampling
#             </span>
#         </label>
#     </div>
#     <div>
#         <label>
#             <input type="radio" name="quiz7">
#             <span>
#                 None
#             </span>
#         </label>
#     </div>
#     <div>
#         <label>
#             <input class="correct_answer" type="radio" name="quiz7">
#             <span>
#                 Mutually exclusive categories
#             </span>
#         </label>
#     </div>
