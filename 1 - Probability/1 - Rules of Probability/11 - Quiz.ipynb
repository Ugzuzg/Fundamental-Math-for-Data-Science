# %% [markdown]
# <style>
# :checked + span {
#     color: red;
# }
# .correct_answer:checked + span {
#         color: green;
# }
# </style>
#
# 1. We roll a 6-sided die. Let’s say event *A* represents rolling an odd number and event *B* represents rolling a number greater than one. Which of the following represents the union of these two events?
#
#     <div>
#     <label>
#         <input type="radio" name="quiz1">
#         <span>{1}</span>
#     </label>
#     </div>
#     <div>
#     <label>
#         <input class="correct_answer" type="radio" name="quiz1">
#         <span>{1, 2, 3, 4, 5, 6}</span>
#     </label>
#     </div>
#     <div>
#     <label>
#         <input type="radio" name="quiz1">
#         <span>{2, 3, 4, 5, 6}</span>
#     </label>
#     </div>
#     <div>
#     <label>
#         <input type="radio" name="quiz1">
#         <span>{1, 3, 5}</span>
#     </label>
#     </div>
#
# 2. We have a bag of ten marbles. There are three orange marbles, two green marbles, and five blue marbles. We take out two marbles without replacement. What is the probability that the first marble we take out is blue AND the second marble we take out is orange?
#     <div>
#     <label>
#         <input type="radio" name="quiz2">
#         <span>1/2</span>
#     </label>
#     </div>
#     <div>
#     <label>
#         <input type="radio" name="quiz2">
#         <span>4/5</span>
#     </label>
#     </div>
#     <div>
#     <label>
#         <input class="correct_answer" type="radio" name="quiz2">
#         <span>1/6</span>
#     </label>
#     </div>
#     <div>
#     <label>
#         <input type="radio" name="quiz2">
#         <span>3/20</span>
#     </label>
#     </div>
#
# 3. Let’s say event A represents rolling an even number on a 6-sided die. Which of the following is NOT true about the complement of event A?
#     <div>
#     <label>
#         <input type="radio" name="quiz3">
#         <span>Event A and its complement capture the entire sample space for rolling one 6-sided die.</span>
#     </label>
#     </div>
#     <div>
#     <label>
#         <input type="radio" name="quiz3">
#         <span>Event A and its complement are mutually exclusive events.</span>
#     </label>
#     </div>
#     <div>
#     <label>
#         <input class="correct_answer" type="radio" name="quiz3">
#         <span>The complement of event A is {2, 4, 6}</span>
#     </label>
#     </div>
#     <div>
#     <label>
#         <input type="radio" name="quiz3">
#         <span>The complement of event A is {1, 3, 5}</span>
#     </label>
#     </div>
#
# 4. Are the following two events independent or dependent?
#     - Event A: rolling an odd number with a 6-sided die
#     - Event B: picking a red marble randomly out of a bag full of marbles
#     <div>
#     <label>
#         <input class="correct_answer" type="radio" name="quiz4">
#         <span>Independent</span>
#     </label>
#     </div>
#     <div>
#     <label>
#         <input type="radio" name="quiz4">
#         <span>Dependent</span>
#     </label>
#     </div>
#
# 5. We roll a 6-sided die. Let’s say event A represents rolling an odd number and event B represents rolling a number greater than one. Which of the following represents the intersection of these two events?
#     <div>
#     <label>
#         <input class="correct_answer" type="radio" name="quiz5">
#         <span>{3, 5}</span>
#     </label>
#     </div>
#     <div>
#     <label>
#         <input type="radio" name="quiz5">
#         <span>{2, 3, 4, 5, 6}</span>
#     </label>
#     </div>
#     <div>
#     <label>
#         <input type="radio" name="quiz5">
#         <span>The intersection is empty</span>
#     </label>
#     </div>
#     <div>
#     <label>
#         <input type="radio" name="quiz5">
#         <span>{1}</span>
#     </label>
#     </div>
#
# 6. The following probabilities map out the event of “Iced Coffee” vs. “No Iced Coffee” in the morning as well as “On-time” vs. “Late” to work given whether or not you got an iced coffee:
#
#     - P(Iced Coffee) = 0.90
#     - P(No Iced Coffee) = 0.10
#     - P(Late | Iced Coffee) = 0.85
#     - P(On-time | Iced Coffee) = 0.15
#     - P(Late | No Iced Coffee) = 0.40
#     - P(On-time | No Iced Coffee) = 0.60
#
#     The four final outcomes come out to:
#
#     - P(Late and Iced Coffee) = 0.765
#     - P(On-time and Iced Coffee) = 0.135
#     - P(Late and No Iced Coffee) = 0.04
#     - P(On-time and No Iced Coffee) = 0.06
#
#     Given all of this information, find P(Iced Coffee | Late): The probability that you had iced coffee in the morning given that you were late.
#
#     Hint: You won’t need to use all the probabilities, and the answers are not in the simplified form!
#
#     <div>
#     <label>
#         <input type="radio" name="quiz6">
#         <span>(0.90 * 0.765)/(0.85 + 0.04)</span>
#     </label>
#     </div>
#     <div>
#     <label>
#         <input class="correct_answer" type="radio" name="quiz6">
#         <span>(0.85 * 0.90)/(0.765 + 0.04)</span>
#     </label>
#     </div>
#     <div>
#     <label>
#         <input type="radio" name="quiz6">
#         <span>(0.85 * 0.90)/0.765</span>
#     </label>
#     </div>
#     <div>
#     <label>
#         <input type="radio" name="quiz6">
#         <span>This probability cannot be quantified with the given information.</span>
#     </label>
#     </div>
#
# 7. We have a bag of 18 marbles. In this bag there are seven orange marbles, five blue marbles, and six green marbles. We take out two marbles from the bag without replacement. Given that the first marble we take out is orange, what is the probability that the next marble we take out is blue?
#     <div>
#     <label>
#         <input type="radio" name="quiz7">
#         <span>5/18</span>
#     </label>
#     </div>
#     <div>
#     <label>
#         <input type="radio" name="quiz7">
#         <span>We cannot quantify this.</span>
#     </label>
#     </div>
#     <div>
#     <label>
#         <input class="correct_answer" type="radio" name="quiz7">
#         <span>5/17</span>
#     </label>
#     </div>
#     <div>
#     <label>
#         <input type="radio" name="quiz7">
#         <span>4/17</span>
#     </label>
#     </div>

# %% [markdown]
# 8. Fill in the code so that the `prob_a_or_b()` function performs the addition rule correctly for events a and b. Within this function:
#
#     - `a` represents a set of outcomes for event A
#     - `b` represents a set of outcomes for event B
#     - `all_possible_outcomes` represents all outcomes in the sample space
#
#     ```python
#     def prob_a_or_b(a, b, all_possible_outcomes):
#         # probability of event a
#         prob_a = len(a)/len(all_possible_outcomes)
#
#         # probability of event b
#         prob_b = len(b)/len(all_possible_outcomes)
#
#         # intersection of events a and b
#         inter = a.intersection(b)
#
#         # probability of intersection of events a and b
#         prob_inter = len(inter)/len(all_possible_outcomes)
#
#         return ___ ___ ___
#     ```
#
#     - `prob_inter`
#     - `inter`
#     - `prob_a + prob_b`
#     - `+`
#     - `-`
#     - `prob_a * prob_b`
#
#     <details>
#         <summary>Answer</summary>
#
#     ```python
#     return prob_a + prob_b - prob_inter
#     ```
#     </details>

# %% [markdown]
# 9. Fill in the function `prob_a_and_b_independent()` so that it returns the probability of two independent events occurring simultaneously. Within this function:
#
#     - `a` represents a set of outcomes within event A
#     - `b` represents a set of outcomes within event B
#     - `all_possible_outcomes` represents all outcomes in the sample space
#
#     ```python
#     def prob_a_and_b_independent(a, b, all_possible_outcomes):
#       prob_a = len(a)/len(all_possible_outcomes)
#
#       prob_b = len(b)/len(all_possible_outcomes)
#
#       prob_a_and_b =  ___ ___ prob_b
#
#       return prob_a_and_b
#     ```
#
#     - `+`
#     - `prob_a`
#     - `*`
#     - `prob_b`
#     - `-`
#
#     <details>
#         <summary>Answer</summary>
#
#     ```python
#     prob_a_and_b = prob_a * prob_b
#     ```
#     </details>
