# %% [markdown]
# <style>
# :checked + span {
#     color: red;
# }
# .correct_answer:checked + span {
#         color: green;
# }
# </style>
#
# 1. Fill in the code below so that we calculate the derivative of the following function accurately:
#
#     $$
#     f(x) = x^2sin(x) + 2
#     $$
#
#     ```python
#     import numpy as np
#     from math import sin
#
#     dx = ___
#     def f(x):
#         return x**2*sin(x) + 2
#     function_y = [f(x) for x in np.arange(0,20,dx)]
#     function_x = [x for x in np.arange(0,20,dx)]
#
#     function_deriv = np___(___,dx)
#     ```
#
#     - `100`
#     - `.deriv`
#     - `function_y`
#     - `.gradient`
#     - `.01`
#     - `1`
#     - `function_x`
#
#     <details>
#         <summary>Answer</summary>
#
#     ```python
#     import numpy as np
#     from math import sin
#
#     dx = .01
#     def f(x):
#         return x**2*sin(x) + 2
#     function_y = [f(x) for x in np.arange(0,20,dx)]
#     function_x = [x for x in np.arange(0,20,dx)]
#
#     function_deriv = np.gradient(function_y,dx)
#     ```
#     </details>
#
# 2. What is the limit of the following function at x=1?
#
#     $$
#     f(x)=2ln(x)-6
#     $$
#
#     <div>
#         <label>
#             <input type="radio" name="quiz2">
#             <span>
#                 -4
#             </span>
#         </label>
#     </div>
#     <div>
#         <label>
#             <input type="radio" name="quiz2">
#             <span>
#                 -Infinity
#             </span>
#         </label>
#     </div>
#     <div>
#         <label>
#             <input class="correct_answer" type="radio" name="quiz2">
#             <span>
#                 -6
#             </span>
#         </label>
#     </div>
#     <div>
#         <label>
#             <input type="radio" name="quiz2">
#             <span>
#                 0
#             </span>
#         </label>
#     </div>
#
# 3. Given the following derivative function:
#
#     $$
#     f'(x) = 2x^2 - 3
#     $$
#
#     At x=1 is the function increasing, decreasing, or neither?
#
#
#     <div>
#         <label>
#             <input type="radio" name="quiz3">
#             <span>
#                 Increasing
#             </span>
#         </label>
#     </div>
#     <div>
#         <label>
#             <input class="correct_answer" type="radio" name="quiz3">
#             <span>
#                 Decreasing
#             </span>
#         </label>
#     </div>
#     <div>
#         <label>
#             <input type="radio" name="quiz3">
#             <span>
#                 Neither
#             </span>
#         </label>
#     </div>
#
# 4. Find the derivative of the following function:
#
#     $$
#     f(x) = 2x^4 + e^x - sin(x)
#     $$
#
#     <div>
#         <label>
#             <input type="radio" name="quiz4">
#             <span>
#
#     $$
#     f'(x) = 6x^3 + e^x + cos(x)
#     $$
#     </span>
#     </label>
#     </div>
#     <div>
#         <label>
#             <input class="correct_answer" type="radio" name="quiz4">
#             <span>
#
#     $$
#     f'(x) = 8x^3 + e^x - cos(x)
#     $$
#     </span>
#     </label>
#     </div>
#     <div>
#         <label>
#             <input type="radio" name="quiz4">
#             <span>
#
#     $$
#     f'(x) = 8x^5 + \frac{1}{x} - cos(x)
#     $$
#     </span>
#     </label>
#     </div>
#     <div>
#         <label>
#             <input type="radio" name="quiz4">
#             <span>
#
#     $$
#     f'(x) = 8x^3 + \frac{1}{x} - cos(x)
#     $$
#     </span>
#     </label>
#     </div>
#
# 5. Which of the following is the correct mathematical representation of the limit definition of a derivative?
#
#     $$
#     f(x) = 2x^4 + e^x - sin(x)
#     $$
#
#     <div>
#         <label>
#             <input class="correct_answer" type="radio" name="quiz5">
#             <span>
#
#     $$
#     \lim_{h \rightarrow 0} \frac{f(x + h)}{h}
#     $$
#     </span>
#     </label>
#     </div>
#     <div>
#         <label>
#             <input type="radio" name="quiz5">
#             <span>
#
#     $$
#     \lim_{x \rightarrow 0} \frac{f(x + h)}{h}
#     $$
#     </span>
#     </label>
#     </div>
#     <div>
#         <label>
#             <input type="radio" name="quiz5">
#             <span>
#
#     $$
#     \lim_{x \rightarrow \infty} \frac{f(x + h)}{h}
#     $$
#     </span>
#     </label>
#     </div>
#     <div>
#         <label>
#             <input type="radio" name="quiz5">
#             <span>
#
#     $$
#     \lim_{h \rightarrow \infty} \frac{f(x + h)}{h}
#     $$
#     </span>
#     </label>
#     </div>
#
# 6. Fill in the text below to accurately describe the product rule for derivatives.
#
#     > Mnemonically, the product rule follows the pattern “___ times derivative of ___ plus second times derivative of ___.”
#
#     - second
#     - second
#     - first
#     - first
#
#     <details>
#         <summary>Answer</summary>
#
#     > Mnemonically, the product rule follows the pattern “**first** times derivative of **second** plus second times derivative of **first**.”
#     </details>
